# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("Stationery_inventory_data.csv")

# %%
df = df[["Availability", "Number of products sold", "Order quantities", "Production volumes", "Inspection results", "Defect rates"]]

# %%
df["Inspection results"].unique()
# Out:
# array(['Pending', 'Fail', 'Pass'], dtype=object)

# %%
mapping = {'Fail': -1, 'Pass': 1, 'Pending': 0}
df.loc[:, 'Inspection results'] = df['Inspection results'].map(mapping).fillna(0)

# %%
df["Inspection results"].unique()
# Out:
# array([0, -1, 1], dtype=object)

# %%
import matplotlib.pyplot as plt
corr = df.corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input

X = df[["Availability", "Number of products sold", "Order quantities", "Production volumes", "Inspection results"]]
y = df["Defect rates"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=16)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

model = Sequential([
    Input(shape=(X_train.shape[1],)),  
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')

model.fit(X_train, y_train, epochs=100, batch_size=3, validation_split=0.2)

predictions = model.predict(X_test)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 1417.9811 - val_loss: 953.4116
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 599.8772 - val_loss: 1125.3545
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 424.2243 - val_loss: 48.4315
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 101.0926 - val_loss: 223.6511
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 254.2824 - val_loss: 58.7861
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 76.9381 - val_loss: 37.2234
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 62.5338 - val_loss: 43.3244
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.5147 - val_loss: 16.3416
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 30.7604 - val_loss: 15.9452
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 36.0243 - val_loss: 22.5790
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 18.4642 - val_loss: 25.7462
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.7987 - val_loss: 15.2605
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1605 - val_loss: 8.2022
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 12.2583 - val_loss: 7.9368
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.0695 - val_loss: 7.1088
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 10.8036 - val_loss: 8.7446
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 13.5619 - val_loss: 8.6062
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6198 - val_loss: 8.0086
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.5840 - val_loss: 6.8657
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0093 - val_loss: 6.4113
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.2870 - val_loss: 5.7378
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.8771 - val_loss: 6.9363
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.1445 - val_loss: 5.5563
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3275 - val_loss: 5.1551
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4706 - val_loss: 4.7241
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3111 - val_loss: 4.7662
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2452 - val_loss: 4.7891
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.3286 - val_loss: 4.7411
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.3192 - val_loss: 4.1093
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.8390 - val_loss: 3.9055
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3209 - val_loss: 5.9293
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0116 - val_loss: 3.9497
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.0991 - val_loss: 3.9119
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.4585 - val_loss: 3.6021
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8932 - val_loss: 4.1013
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.3020 - val_loss: 3.8643
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8417 - val_loss: 3.7099
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7885 - val_loss: 3.4582
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4686 - val_loss: 3.5585
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.2339 - val_loss: 2.8687
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.9371 - val_loss: 2.8613
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7929 - val_loss: 3.5205
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4598 - val_loss: 3.0656
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0754 - val_loss: 2.5379
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5793 - val_loss: 2.7674
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.3652 - val_loss: 3.3114
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4949 - val_loss: 2.7730
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1025 - val_loss: 2.3570
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.0220 - val_loss: 3.8435
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.6898 - val_loss: 2.1689
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.5168 - val_loss: 2.6246
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6389 - val_loss: 2.0757
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8733 - val_loss: 1.7397
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7716 - val_loss: 1.7649
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7402 - val_loss: 1.8234
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3602 - val_loss: 1.6568
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5726 - val_loss: 2.9377
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1041 - val_loss: 1.8104
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5325 - val_loss: 1.6997
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.3952 - val_loss: 1.9302
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9985 - val_loss: 1.1315
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3366 - val_loss: 6.1542
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9005 - val_loss: 2.3392
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1244 - val_loss: 1.5439
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5941 - val_loss: 1.4657
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6018 - val_loss: 2.4723
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9650 - val_loss: 1.3393
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4073 - val_loss: 1.6383
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7155 - val_loss: 1.2733
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3100 - val_loss: 1.4794
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8598 - val_loss: 1.7144
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7061 - val_loss: 0.8996
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5515 - val_loss: 2.5088
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2308 - val_loss: 1.0711
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4225 - val_loss: 1.0470
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2096 - val_loss: 1.4158
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3679 - val_loss: 0.9737
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4855 - val_loss: 1.6142
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3418 - val_loss: 1.0152
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2208 - val_loss: 1.0155
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3350 - val_loss: 1.1439
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3470 - val_loss: 0.8561
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1524 - val_loss: 1.5451
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4546 - val_loss: 0.8256
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1858 - val_loss: 0.9423
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1717 - val_loss: 1.2110
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2190 - val_loss: 1.1992
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1362 - val_loss: 0.8606
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1476 - val_loss: 1.0697
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2158 - val_loss: 0.8169
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1295 - val_loss: 1.2048
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3183 - val_loss: 0.7680
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2286 - val_loss: 0.9983
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1986 - val_loss: 1.1467
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2048 - val_loss: 0.7682
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0851 - val_loss: 1.2937
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1838 - val_loss: 0.8972
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1722 - val_loss: 0.8810
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0579 - val_loss: 1.1704
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1202 - val_loss: 0.7943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(X_test)

# Calculate MSE
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# Calculate R2 score
r2 = r2_score(y_test, y_pred)
print("R-squared (R²):", r2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Mean Squared Error (MSE): 83.46301
# R-squared (R²): -63.10731661490529

# %%
import pickle

filename = "Stationery_inventory_data_deficit_rates.pkl"

with open(filename, "wb") as file:
    pickle.dump(model, file)

print(f"Model successfully saved to {filename}")
# Out:
# Model successfully saved to Stationery_inventory_data_deficit_rates.pkl
